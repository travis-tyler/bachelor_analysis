# %% [markdown]
# Data source: https://www.kaggle.com/fivethirtyeight/fivethirtyeight-bachelorette-dataset?select=bachelorette.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.DataFrame(pd.read_csv('../resources/bachelorette.csv'))
df
# Out:
#              SHOW  SEASON     CONTESTANT ELIMINATION-1 ELIMINATION-2  \
# 0            SHOW  SEASON             ID             1             2
# 1    Bachelorette      13     13_BRYAN_A            R1           NaN
# 2    Bachelorette      13     13_PETER_K           NaN             R
# 3    Bachelorette      13      13_ERIC_B           NaN           NaN
# 4    Bachelorette      13      13_DEAN_U           NaN             R
# ..            ...     ...            ...           ...           ...
# 916      Bachelor      01  01_KRISTINA_X             E           NaN
# 917      Bachelor      01      01_LISA_X             E           NaN
# 918      Bachelor      01     01_PAULA_X             E           NaN
# 919      Bachelor      01    01_RACHEL_X             E           NaN
# 920      Bachelor      01     01_WENDI_X             E           NaN
#
#     ELIMINATION-3 ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7  \
# ...

# %%
bachelorette_r1 = df.loc[(df['ELIMINATION-1']=='R1') & (df['SHOW']=='Bachelorette')]
bachelor_r1 = df.loc[(df['ELIMINATION-1']=='R1') & (df['SHOW']=='Bachelor')]

bachelorette_winner = df.loc[df['SHOW']=='Bachelorette'].groupby('SEASON').first()
bachelor_winner = df.loc[df['SHOW']=='Bachelor'].groupby('SEASON').first()
bachelor_winner
# Out:
#             SHOW      CONTESTANT ELIMINATION-1 ELIMINATION-2 ELIMINATION-3  \
# SEASON
# 01      Bachelor     01_AMANDA_M             E             E             E
# 02      Bachelor     02_HELENE_E             E             E             E
# 03      Bachelor        03_JEN_X             E             E             E
# 04      Bachelor     04_Kelly-Jo             E            ED             E
# 05      Bachelor    05_JESSICA_B            R1             E             E
# 06      Bachelor         06_Mary             E             E             E
# 07      Bachelor     07_Sarah B.             R             R             R
# 08      Bachelor      08_Sarah_S             E             R             R
# 09      Bachelor   09_JENNIFER_W            R1             R             R
# 10      Bachelor      10_TESSA_H            R1             R             R
# 11      Bachelor     11_DEANNA_P            R1             R             R
# ...
